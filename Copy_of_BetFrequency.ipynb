# %% [markdown]
# <a href="https://colab.research.google.com/github/theegannaicker/MicrosoftLearning-DP-200-Implementing-an-Azure-Data-Solution-/blob/master/Copy_of_BetFrequency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pandas as pd

df = pd.read_excel('DataSet2.xlsx')
df
# Out:
#       ClientID  Avg_Days_Between_bets  DaysSinceLastBet
# 0      9786129                     16                 6
# 1      6077951                      5                 3
# 2     15351827                      3                14
# 3      1230560                      1                 1
# 4     14902757                      2                 6
# ...        ...                    ...               ...
# 9995  13167378                      0                39
# 9996   5333330                      0                40
# 9997    104534                      2                 3
# 9998   1629268                      4                49
# 9999   4221436                      1                 1
#
# [10000 rows x 3 columns]

# %%
def label_bettor(row):
    if 1 <= row['Avg_Days_Between_bets'] <= 2 and row['DaysSinceLastBet'] <= 3:
        return 'Daily'
    elif 2 <= row['Avg_Days_Between_bets'] <= 14 and row['DaysSinceLastBet'] <= 29:
        return 'Weekly'
    elif 15 <= row['Avg_Days_Between_bets'] <= 61 and row['DaysSinceLastBet'] <= 61:
        return 'Monthly'
    else:
        return 'Occasional'

df['Bet Frequency'] = df.apply(label_bettor, axis=1)
df
# Out:
#       ClientID  Avg_Days_Between_bets  DaysSinceLastBet Bet Frequency
# 0      9786129                     16                 6       Monthly
# 1      6077951                      5                 3        Weekly
# 2     15351827                      3                14        Weekly
# 3      1230560                      1                 1         Daily
# 4     14902757                      2                 6        Weekly
# ...        ...                    ...               ...           ...
# 9995  13167378                      0                39    Occasional
# 9996   5333330                      0                40    Occasional
# 9997    104534                      2                 3         Daily
# 9998   1629268                      4                49    Occasional
# 9999   4221436                      1                 1         Daily
#
# [10000 rows x 4 columns]

# %%
X = df[['Avg_Days_Between_bets', 'DaysSinceLastBet']]
y = df['Bet Frequency']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train the model
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Daily       1.00      1.00      1.00       826
#      Monthly       1.00      1.00      1.00       132
#   Occasional       1.00      1.00      1.00      1023
#       Weekly       1.00      1.00      1.00      1019
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
new_df = pd.read_excel('NewDataForTest.xlsx')
new_df
# Out:
#          ClientId  Avg_Days_Between_bets  DaysSinceLastBet
# 0        18720315                      1                 3
# 1          204176                      1                 2
# 2         3779276                      1                 2
# 3        12085540                      1                 6
# 4         6967083                     37                 3
# ...           ...                    ...               ...
# 1048570    852497                      1                 3
# 1048571   2964234                      1                 1
# 1048572   3241557                     12                23
# 1048573   3335875                      1                53
# 1048574  18390058                      0                35
#
# [1048575 rows x 3 columns]

# %%
X_new = new_df[['Avg_Days_Between_bets', 'DaysSinceLastBet']]

# %%
new_df['PredictedBetFrequency'] = clf.predict(X_new)

# %%
new_df
# Out:
#          ClientId  Avg_Days_Between_bets  DaysSinceLastBet  \
# 0        18720315                      1                 3
# 1          204176                      1                 2
# 2         3779276                      1                 2
# 3        12085540                      1                 6
# 4         6967083                     37                 3
# ...           ...                    ...               ...
# 1048570    852497                      1                 3
# 1048571   2964234                      1                 1
# 1048572   3241557                     12                23
# 1048573   3335875                      1                53
# 1048574  18390058                      0                35
#
#         PredictedBetFrequency
# 0                       Daily
# 1                       Daily
# 2                       Daily
# 3                  Occasional
# 4                     Monthly
# ...                       ...
# 1048570                 Daily
# ...
